# %%
import json
import pandas as pd
import hvplot.pandas
import requests
import numpy as np
from config import openweather_key

sales_data_path = "/Users/matthewflanagan/Desktop/Data Analytics Work/Project 1/Project_1/file.csv"


sales_data = pd.read_csv(sales_data_path)

sales_data.head()
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
#    Unnamed: 0  CustomerID Gender Location  Tenure_Months  Transaction_ID  \
# 0           0     17850.0      M  Chicago           12.0         16679.0
# 1           1     17850.0      M  Chicago           12.0         16680.0
# 2           2     17850.0      M  Chicago           12.0         16696.0
# 3           3     17850.0      M  Chicago           12.0         16699.0
# 4           4     17850.0      M  Chicago           12.0         16700.0
#
#   Transaction_Date     Product_SKU  \
# 0       2019-01-01  GGOENEBJ079499
# 1       2019-01-01  GGOENEBJ079499
# 2       2019-01-01  GGOENEBQ078999
# 3       2019-01-01  GGOENEBQ079099
# 4       2019-01-01  GGOENEBJ079499
#
#                                  Product_Description Product_Category  ...  \
# 0  Nest Learning Thermostat 3rd Gen-USA - Stainle...         Nest-USA  ...
# 1  Nest Learning Thermostat 3rd Gen-USA - Stainle...         Nest-USA  ...
# 2             Nest Cam Outdoor Security Camera - USA         Nest-USA  ...
# 3    Nest Protect Smoke + CO White Battery Alarm-USA         Nest-USA  ...
# 4  Nest Learning Thermostat 3rd Gen-USA - Stainle...         Nest-USA  ...
#
#    Avg_Price  Delivery_Charges  Coupon_Status  GST      Date Offline_Spend  \
# 0     153.71               6.5           Used  0.1  1/1/2019        4500.0
# 1     153.71               6.5           Used  0.1  1/1/2019        4500.0
# 2     122.77               6.5       Not Used  0.1  1/1/2019        4500.0
# 3      81.50               6.5        Clicked  0.1  1/1/2019        4500.0
# 4     153.71               6.5        Clicked  0.1  1/1/2019        4500.0
#
#    Online_Spend  Month  Coupon_Code Discount_pct
# 0        2424.5      1       ELEC10         10.0
# 1        2424.5      1       ELEC10         10.0
# 2        2424.5      1       ELEC10         10.0
# 3        2424.5      1       ELEC10         10.0
# 4        2424.5      1       ELEC10         10.0
#
# [5 rows x 21 columns]

# %%
#dropping redundant and un-needed columns
sales_data_cleaned = sales_data.drop(['Unnamed: 0', 'Tenure_Months', 'Transaction_Date', 'GST', 'Offline_Spend', 'Online_Spend', 'Month', 'Coupon_Code', 'Discount_pct'], axis=1)


#dropping rows that have incomplete data
sales_data_cleaned = sales_data_cleaned.dropna()


#converting the date to unix time format for the api request & and adding it to a column
sales_data_cleaned['Date'] = pd.to_datetime(sales_data_cleaned['Date'])

sales_data_cleaned["Unix Date"] = sales_data_cleaned['Date'].apply(lambda x: int(x.timestamp()))


sales_data_cleaned.head()
# Out:
#    CustomerID Gender Location  Transaction_ID     Product_SKU  \
# 0     17850.0      M  Chicago         16679.0  GGOENEBJ079499
# 1     17850.0      M  Chicago         16680.0  GGOENEBJ079499
# 2     17850.0      M  Chicago         16696.0  GGOENEBQ078999
# 3     17850.0      M  Chicago         16699.0  GGOENEBQ079099
# 4     17850.0      M  Chicago         16700.0  GGOENEBJ079499
#
#                                  Product_Description Product_Category  \
# 0  Nest Learning Thermostat 3rd Gen-USA - Stainle...         Nest-USA
# 1  Nest Learning Thermostat 3rd Gen-USA - Stainle...         Nest-USA
# 2             Nest Cam Outdoor Security Camera - USA         Nest-USA
# 3    Nest Protect Smoke + CO White Battery Alarm-USA         Nest-USA
# 4  Nest Learning Thermostat 3rd Gen-USA - Stainle...         Nest-USA
#
#    Quantity  Avg_Price  Delivery_Charges Coupon_Status       Date   Unix Date
# 0       1.0     153.71               6.5          Used 2019-01-01  1546300800
# 1       1.0     153.71               6.5          Used 2019-01-01  1546300800
# 2       2.0     122.77               6.5      Not Used 2019-01-01  1546300800
# 3       1.0      81.50               6.5       Clicked 2019-01-01  1546300800
# 4       1.0     153.71               6.5       Clicked 2019-01-01  1546300800

# %%
#getting 100 random rows for each city
np.random.seed(42)

def random_rows(group):
    return group.sample(min(len(group), 50))

sales_data_random_cleaned = sales_data_cleaned.groupby('Location', group_keys=False).apply(random_rows)


#hard cording the city coordinates
city_coordinates = {
    "Chicago": (41.8781, -87.6298),
    "California": (36.7783, -119.4179),
    "New Jersey": (40.0583, -74.4057),
    "New York": (40.7128, -74.0060),
    "Washington DC": (38.8951, -77.0364),
}

#adding latitude and longitude columns
sales_data_random_cleaned["Lat"] = sales_data_random_cleaned["Location"].map(city_coordinates).apply(lambda x: x[0])
sales_data_random_cleaned["Lon"] = sales_data_random_cleaned["Location"].map(city_coordinates).apply(lambda x: x[1])


#adding blank weather conditions column
sales_data_random_cleaned["Weather Conditions"] = ""

sales_data_random_cleaned.head()
# Out:
#        CustomerID Gender    Location  Transaction_ID     Product_SKU  \
# 23680     14307.0      F  California         38830.0  GGOEGOAR013099
# 6316      14911.0      F  California         45554.0  GGOEGAYB068026
# 44290     17085.0      F  California         31959.0  GGOEGOCB017499
# 23304     17787.0      M  California         39212.0  GGOENEBJ079499
# 25591     14527.0      M  California         38656.0  GGOEGBJC014399
#
#                                      Product_Description Product_Category  \
# 23680                     Google Stylus Pen w/ LED Light           Office
# 6316          Google Youth Baseball Raglan Heather/Black          Apparel
# 44290                                Leatherette Journal           Office
# 23304  Nest Learning Thermostat 3rd Gen-USA - Stainle...         Nest-USA
# 25591                                    Google Tote Bag             Bags
#
#        Quantity  Avg_Price  Delivery_Charges Coupon_Status       Date  \
# 23680      75.0       4.40             82.48       Clicked 2019-09-23
# 6316        1.0      10.18              6.50       Clicked 2019-12-04
# 44290      30.0       8.79             36.06       Clicked 2019-07-06
# 23304       1.0     149.00              6.00      Not Used 2019-09-27
# 25591       1.0       9.99              6.00       Clicked 2019-09-21
#
#         Unix Date      Lat       Lon Weather Conditions
# 23680  1569196800  36.7783 -119.4179
# 6316   1575417600  36.7783 -119.4179
# 44290  1562371200  36.7783 -119.4179
# 23304  1569542400  36.7783 -119.4179
# 25591  1569024000  36.7783 -119.4179

# %%
#BE CAREFUL RUNNING API REQUEST AS WE ONLY GET 1000 PER DAY
#THIS DATA SET CONTAINS 250 PER RUN!!!
#takes ~2min to run

url = "https://api.openweathermap.org/data/3.0/onecall/timemachine?"
units = "imperial"


#setting the parameters for the api request
for index, row in sales_data_random_cleaned.iterrows():
    latitude = row["Lat"]
    longitude = row["Lon"]
    date = row["Unix Date"]

    params = {
    "lat": latitude,
    "lon": longitude,
    "dt": date,
    "apiKey":openweather_key,
    "units": units
}


    response = requests.get(url, params=params)

    response = response.json()

  
 #getting the weather description for each row and putting it in the weather conditions column
#add temperature column
    try:
        sales_data_random_cleaned.loc[index, "Weather Conditions"] = response["data"][0]["weather"][0]["description"]
        
    except KeyError as e:
        print("No Weather Data Found")


sales_data_random_cleaned.head(25)
# Out:
#        CustomerID Gender    Location  Transaction_ID     Product_SKU  \
# 31125     14911.0      F  California         19784.0  GGOENEBJ079499
# 18033     17596.0      F  California         22388.0  GGOEGDHC018299
# 44004     14911.0      F  California         32456.0  GGOEGFKQ020799
# 1050      12433.0      M  California         17529.0  GGOENEBB078899
# 20023     15456.0      M  California         30075.0  GGOEGFKA022299
# 50920     14068.0      M  California         40417.0  GGOEGDHC018299
# 2902      13777.0      F  California         17867.0  GGOEYAAB031815
# 33090     18156.0      F  California         20638.0  GGOEAAXC066428
# 7772      14156.0      F  California         47409.0  GGOENEBQ086799
# 6308      14911.0      F  California         45524.0  GGOEGAEB027815
# 51945     13230.0      M  California         40191.0  GGOEWFKA082999
# 17178     18119.0      F  California         23700.0  GGOEGAFB035815
# 47043     16875.0      F  California         32823.0  GGOEGFYQ016599
# 11642     16833.0      F  California         35180.0  GGOEGAAJ032313
# 40118     17576.0      F  California         28536.0  GGOEGAXC065228
# 9356      18106.0      F  California         37122.0  GGOENEBQ079199
# 11329     13093.0      M  California         36768.0  GGOEGAAC032117
# 31509     15545.0      F  California         20104.0  GGOENEBB078899
# 37808     12731.0      F  California         26352.0  GGOEGHGC019799
# 6147      16705.0      F  California         46080.0  GGOEGAEH090615
# 47353     17340.0      F  California         32389.0  GGOEGHGC019799
# 41156     17894.0      F  California         28623.0  GGOEGAAC032113
# 37551     16265.0      M  California         26306.0  GGOEGDHC015299
# 9614      12728.0      F  California         36101.0  GGOENEBB078899
# 31114     14911.0      F  California         19775.0  GGOENEBJ079499
#
#                                      Product_Description Product_Category  \
# 31125  Nest Learning Thermostat 3rd Gen-USA - Stainle...         Nest-USA
# 18033                          Google 22 oz Water Bottle        Drinkware
# 44004                                Google Doodle Decal           Office
# 1050               Nest Cam Indoor Security Camera - USA         Nest-USA
# 20023                               Keyboard DOT Sticker           Office
# 50920                          Google 22 oz Water Bottle        Drinkware
# 2902           YouTube Men's Short Sleeve Hero Tee Black          Apparel
# 33090          Android Toddler Short Sleeve T-shirt Aqua          Apparel
# 7772                             Nest Thermostat E - USA             Nest
# 6308          Google Women's Short Sleeve Hero Tee Black          Apparel
# 51945                    Waze Baby on Board Window Decal             Waze
# 17178                           Google Men's  Zip Hoodie          Apparel
# 47043                         Foam Can and Bottle Cooler        Drinkware
# 11642        Google Men's Short Sleeve Hero Tee Charcoal          Apparel
# 40118     Google Toddler Short Sleeve T-shirt Royal Blue          Apparel
# 9356       Nest Protect Smoke + CO White Wired Alarm-USA         Nest-USA
# 11329      Google Men's Short Sleeve Hero Tee Light Blue          Apparel
# 31509              Nest Cam Indoor Security Camera - USA         Nest-USA
# 37808                                  Google Sunglasses        Lifestyle
# 6147                                    Google Tee Green          Apparel
# 47353                                  Google Sunglasses        Lifestyle
# 41156      Google Men's Short Sleeve Hero Tee Light Blue          Apparel
# 37551                      23 oz Wide Mouth Sport Bottle        Drinkware
# 9614               Nest Cam Indoor Security Camera - USA         Nest-USA
# 31114  Nest Learning Thermostat 3rd Gen-USA - Stainle...         Nest-USA
#
#        Quantity  Avg_Price  Delivery_Charges Coupon_Status       Date  \
# 31125       1.0     149.00              6.50          Used 2019-02-06
# 18033      32.0       2.99              6.50       Clicked 2019-03-08
# 44004       1.0       2.39             49.73       Clicked 2019-07-12
# 1050        1.0     122.77              6.50       Clicked 2019-01-10
# 20023       2.0       1.50              6.00       Clicked 2019-06-11
# 50920      50.0       2.99              6.00      Not Used 2019-10-11
# 2902        1.0      17.53              6.50       Clicked 2019-01-14
# 33090       1.0      13.59              6.50          Used 2019-02-17
# 7772        1.0     100.91              6.50       Clicked 2019-12-18
# 6308        1.0       8.65              6.00       Clicked 2019-12-04
# 51945       1.0       2.39              6.00       Clicked 2019-10-09
# 17178       1.0      55.99              6.50       Clicked 2019-03-20
# 47043      20.0       1.39              6.00          Used 2019-07-16
# 11642       1.0      10.63              6.00       Clicked 2019-08-10
# 40118       1.0      16.99              6.00          Used 2019-05-21
# 9356        1.0      79.00              6.00          Used 2019-08-31
# 11329       1.0      15.19              6.00       Clicked 2019-08-28
# 31509       1.0     119.00              6.50      Not Used 2019-02-10
# 37808       3.0       2.80             19.99      Not Used 2019-04-24
# 6147        1.0      17.93              6.50          Used 2019-12-08
# 47353       1.0       2.80              6.00      Not Used 2019-07-11
# 41156       1.0      15.19              6.00       Clicked 2019-05-22
# 37551       5.0      10.99             19.99          Used 2019-04-24
# 9614        1.0     119.00              6.00          Used 2019-08-19
# 31114       1.0     149.00              6.50          Used 2019-02-06
#
#       Coupon_Code  Discount_pct   Unix Date      Lat       Lon  \
# 31125      ELEC20          20.0  1549411200  36.7783 -119.4179
# 18033     EXTRA30          30.0  1552003200  36.7783 -119.4179
# 44004       OFF10          10.0  1562889600  36.7783 -119.4179
# 1050       ELEC10          10.0  1547078400  36.7783 -119.4179
# 20023       OFF30          30.0  1560211200  36.7783 -119.4179
# 50920     EXTRA10          10.0  1570752000  36.7783 -119.4179
# 2902       SALE10          10.0  1547424000  36.7783 -119.4179
# 33090      SALE20          20.0  1550361600  36.7783 -119.4179
# 7772         NE30          30.0  1576627200  36.7783 -119.4179
# 6308       SALE30          30.0  1575417600  36.7783 -119.4179
# 51945      WEMP10          10.0  1570579200  36.7783 -119.4179
# 17178      SALE30          30.0  1553040000  36.7783 -119.4179
# 47043     EXTRA10          10.0  1563235200  36.7783 -119.4179
# 11642      SALE20          20.0  1565395200  36.7783 -119.4179
# 40118      SALE20          20.0  1558396800  36.7783 -119.4179
# 9356       ELEC20          20.0  1567209600  36.7783 -119.4179
# 11329      SALE20          20.0  1566950400  36.7783 -119.4179
# 31509      ELEC20          20.0  1549756800  36.7783 -119.4179
# 37808     EXTRA10          10.0  1556064000  36.7783 -119.4179
# 6147       SALE30          30.0  1575763200  36.7783 -119.4179
# 47353     EXTRA10          10.0  1562803200  36.7783 -119.4179
# 41156      SALE20          20.0  1558483200  36.7783 -119.4179
# 37551     EXTRA10          10.0  1556064000  36.7783 -119.4179
# 9614       ELEC20          20.0  1566172800  36.7783 -119.4179
# 31114      ELEC20          20.0  1549411200  36.7783 -119.4179
#
#       Weather Conditions
# 31125         light rain
# 18033         light rain
# 44004          clear sky
# 1050       moderate rain
# 20023    overcast clouds
# 50920          clear sky
# 2902     overcast clouds
# 33090   scattered clouds
# 7772     overcast clouds
# 6308                mist
# 51945          clear sky
# 17178         light rain
# 47043          clear sky
# 11642          clear sky
# 40118    overcast clouds
# 9356           clear sky
# 11329          clear sky
# 31509   scattered clouds
# 37808          clear sky
# 6147       moderate rain
# 47353         few clouds
# 41156         light rain
# 37551          clear sky
# 9614           clear sky
# 31114         light rain

# %%
###How does inclement weather affect shopping habits?
## compare if the volume of shopping increased during inclement weather (light rain, moderate rain, heavy rain, mist, overcast?) and good weather (clear sky, scattered clouds, etc.)
## scatter plot & lin regress & bar graph maybe


#sergio

# %%
#how do extreme temps affect online shopping habits
# compare if temperatures affect online shopping habits (scatter plot & lin regress)

##larry

# %%
#how does season affect online shopping habits


#Emely

# %%
#how does gender impact online shopping habits

#Emely

# %%
#does the availability of discounts or promotions influence online shopping behavior on online shopping habits  

#rebecca

# %%
#are promotions or discounts used more often during inclement weather

#rebecca

# %%
#is there a correlation between the peak shopping season and the occurrence of the most extreme temperatures within a given geographical region

#Larry

# %%
#does the severity of weather influence online shopping behavior?

#Sergio

# %%
#is there a correlation between inclement weather and product category?

#matt
